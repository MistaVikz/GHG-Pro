# %%
# %load_ext autoreload
# %autoreload 2

# %%
# project_risk.py
# Author: Mark Vickers
# Date Created: 2024-05-11
# Description: Calculates project risk scores and generates output tables

from utils.io import *
from utils.risk_calculation import *
from utils.analysis import *
import logging

NUM_YEARS = 10

logging.basicConfig(level=logging.INFO)

if __name__ == "__main__":
    try:
        risk_bucket_count, risk_factor_count, df_project, df_default_rates, df_recovery_potential = load_and_process_data()

        if valid_project_data(df_project,risk_bucket_count,risk_factor_count) and check_df_format(df_default_rates, df_recovery_potential):        

            # Calculate Risk Bucket Risk Scores and Ratings for each risk bucket 
            df_project = calculate_risk_bucket_scores(df_project,risk_bucket_count,risk_factor_count) 

            for i in range(1, risk_bucket_count + 1):
                df_project[f'risk_bucket_{i}_rating'] = score_to_rating_vectorized(df_project[f'risk_bucket_{i}_score'])
            
            # Prepare for the simulation
            df_project = calculate_yearly_exposure(df_project, df_default_rates, df_recovery_potential, risk_bucket_count)
            df_project = calculate_yearly_expected_value(df_project, risk_bucket_count)
            df_project = calculate_yearly_standard_deviation(df_project,risk_bucket_count)
        
            # Run the yearly simulations for all projects
            df_project = run_simulation(df_project, risk_bucket_count)
            overall_expected_value_percentage = df_project[[f'project_expected_value_percentage_year_{year}' for year in range(1, NUM_YEARS+1)]].mean(axis=1, skipna=True) * 10
            df_project['overall_project_rating'] = score_to_rating_vectorized(overall_expected_value_percentage)

            # Calculate Project Output Tables
            df_counts = pd.DataFrame(df_project['overall_project_rating'].value_counts()).reset_index()
            df_counts.columns = ['overall_project_rating', 'counts']
            top_projects, bottom_projects = calculate_top_bottom_projects(df_project, 10, ['project_id', 'project_name', 'country', 'technology', 'counterparty', 'start_year'])            
            country_table = create_group_table(df_project, 'country')
            technology_table = create_group_table(df_project, 'technology')
            counterparty_table = create_group_table(df_project, 'counterparty')
            total_volumes_per_year = calculate_total_volumes_by_year(df_project)
            
            # Display and Export Data
            display_project_risk_output(df_counts, top_projects, bottom_projects, country_table, technology_table, counterparty_table, total_volumes_per_year)
            output_folder = create_output_folder()
            export_project_risk_output(output_folder, top_projects, bottom_projects, country_table, technology_table, counterparty_table, df_counts, total_volumes_per_year)
            export_ghg_data(output_folder, df_project,df_default_rates,df_recovery_potential)
        else:
            print("Data not loaded properly from GHG_Data.xlsx")

    except FileNotFoundError as e:
        logging.error(f"File not found: {str(e)}")
    except pd.errors.EmptyDataError as e:
        logging.error(f"Empty data error: {str(e)}")
    except TypeError as e:
        logging.error(f"Type error occurred: {str(e)}")
    except ValueError as e:
        logging.error(f"Value error occurred: {str(e)}")
    except Exception as e:
        logging.error(f"An unexpected error occurred: {str(e)}")
        raise
# Out:
# Project Rating Distribution
# | overall_project_rating   |   counts |
# |:-------------------------|---------:|
# | C                        |       70 |
# | Speculative              |       45 |
# | Investment               |       10 |
#
# Highest Performing Projects
# |   rank |   project_id | project_name                            | country      | technology               | counterparty            |   start_year |   average_expected_value |
# |-------:|-------------:|:----------------------------------------|:-------------|:-------------------------|:------------------------|-------------:|-------------------------:|
# |      1 |           25 | Renewable Solutions Solar Site B        | USA          | Renewable Energy         | Non-Profit Organization |         2004 |                 0.922372 |
# |      2 |           64 | Biofuel Site C Sustainable Futures      | Spain        | Energy Efficiency        | Private Company         |         2002 |                 0.899173 |
# |      3 |           61 | Reserve Sustainable Futures Sustainable | Indonesia    | Green Building Practices | Non-Profit Organization |         2007 |                 0.898162 |
# |      4 |           28 | Pure Planet Biofuel Site D              | China        | Sustainable Agriculture  | Community Group         |         2014 |                 0.849858 |
# |      5 |          107 | Site D Clean Power Co. Wind             | Indonesia    | Energy Efficiency        | NGO                     |         2001 |                 0.848809 |
# |      6 |           35 | Site A Clean Power Co. Wind             | South Africa | Green Building Practices | Non-Profit Organization |         2008 |                 0.798185 |
# |      7 |           24 | BioEnergy Systems Site A Biofuel        | Poland       | Carbon Capture           | Government Agency       |         2014 |                 0.77624  |
# |      8 |          120 | Recycling Reserve BioEnergy Systems     | USA          | Forestry Management      | Private Company         |         2012 |                 0.776174 |
# |      9 |            5 | Clean Power Co. Conservation Site D     | USA          | Waste-to-Energy          | Government Agency       |         2010 |                 0.776108 |
# |     10 |           34 | North GreenTech Inc. Sustainable        | Canada       | Carbon Capture           | NGO                     |         2001 |                 0.76705  |
#
# Lowest Performing Projects
# |   rank |   project_id | project_name                            | country     | technology               | counterparty            |   start_year |   average_expected_value |
# |-------:|-------------:|:----------------------------------------|:------------|:-------------------------|:------------------------|-------------:|-------------------------:|
# |      1 |           65 | Sustainable East Clean Power Co.        | Japan       | Green Building Practices | NGO                     |         2013 |                0.0490553 |
# |      2 |           18 | Nature's Way Geothermal North           | France      | Renewable Energy         | Non-Profit Organization |         2002 |                0.061053  |
# |      3 |           93 | Solar Nature's Way South                | Spain       | Waste Management         | Non-Profit Organization |         2005 |                0.067435  |
# |      4 |           23 | ClimateCare Ltd. Site C Biofuel         | South Korea | Green Building Practices | Non-Profit Organization |         2006 |                0.06865   |
# |      5 |           84 | BioEnergy Systems Hydro East            | Italy       | Waste-to-Energy          | NGO                     |         2012 |                0.0798792 |
# |      6 |           96 | Sustainable ClimateCare Ltd. North      | Indonesia   | Waste-to-Energy          | Private Company         |         2011 |                0.0802812 |
# |      7 |           46 | Geothermal EarthFirst Energy North      | Mexico      | Waste-to-Energy          | NGO                     |         2008 |                0.0817935 |
# |      8 |           69 | Site C Eco-Friendly Sustainable Futures | Sweden      | Water Conservation       | Non-Profit Organization |         2004 |                0.0885056 |
# |      9 |          108 | Site A Wind EcoEnergy Corp.             | South Korea | Waste-to-Energy          | Government Agency       |         2014 |                0.0887885 |
# |     10 |           11 | Biofuel EcoEnergy Corp. West            | Turkey      | Waste Management         | Non-Profit Organization |         2009 |                0.0892196 |
#
# Overall Project Rating Distribution by Country
# | country      |   Total Offered Volume |   Total Projects |   C (%) |   Speculative (%) |   Investment (%) |
# |:-------------|-----------------------:|-----------------:|--------:|------------------:|-----------------:|
# | Australia    |               25512766 |                5 |   20    |             80    |             0    |
# | Brazil       |               30753353 |                6 |   83.33 |             16.67 |             0    |
# | Canada       |               29047653 |                6 |   33.33 |             50    |            16.67 |
# | China        |               46153538 |                9 |   44.44 |             44.44 |            11.11 |
# | France       |               62041097 |               11 |   72.73 |             27.27 |             0    |
# | Germany      |               23709000 |                5 |   60    |             40    |             0    |
# | India        |               45406723 |                9 |   55.56 |             44.44 |             0    |
# | Indonesia    |               47505169 |                9 |   33.33 |             44.44 |            22.22 |
# | Italy        |               19079482 |                4 |   50    |             50    |             0    |
# | Japan        |               19832802 |                4 |   75    |             25    |             0    |
# | Mexico       |               33551395 |                6 |   66.67 |             33.33 |             0    |
# | Netherlands  |                5143421 |                1 |  100    |              0    |             0    |
# | Poland       |               21408301 |                4 |   75    |              0    |            25    |
# | Russia       |               21329826 |                4 |   50    |             50    |             0    |
# | South Africa |               27240141 |                5 |   60    |             20    |            20    |
# | South Korea  |               37790466 |                7 |   71.43 |             28.57 |             0    |
# | Spain        |               26240555 |                5 |   40    |             40    |            20    |
# | Sweden       |               13322942 |                3 |  100    |              0    |             0    |
# | Turkey       |               69155646 |               13 |   69.23 |             30.77 |             0    |
# | USA          |               44449490 |                9 |   22.22 |             44.44 |            33.33 |
#
# Overall Project Rating Distribution by Technology
# | technology               |   Total Offered Volume |   Total Projects |   C (%) |   Speculative (%) |   Investment (%) |
# |:-------------------------|-----------------------:|-----------------:|--------:|------------------:|-----------------:|
# | Air Pollution Reduction  |               49486707 |               10 |   80    |             20    |             0    |
# | Carbon Capture           |               55125485 |               10 |   60    |             20    |            20    |
# | Energy Efficiency        |               83224225 |               16 |   56.25 |             31.25 |            12.5  |
# | Forestry Management      |               77654490 |               15 |   46.67 |             46.67 |             6.67 |
# | Green Building Practices |               63074070 |               12 |   41.67 |             41.67 |            16.67 |
# | Renewable Energy         |               47969203 |               10 |   50    |             40    |            10    |
# | Sustainable Agriculture  |               81409247 |               16 |   43.75 |             50    |             6.25 |
# | Waste Management         |               85170396 |               15 |   66.67 |             33.33 |             0    |
# | Waste-to-Energy          |               70250369 |               14 |   57.14 |             35.71 |             7.14 |
# | Water Conservation       |               35309574 |                7 |   71.43 |             28.57 |             0    |
#
# Overall Project Rating Distribution by Counterparty
# | counterparty            |   Total Offered Volume |   Total Projects |   C (%) |   Speculative (%) |   Investment (%) |
# |:------------------------|-----------------------:|-----------------:|--------:|------------------:|-----------------:|
# | Community Group         |              125878539 |               24 |   50    |             45.83 |             4.17 |
# | Government Agency       |              120810112 |               23 |   69.57 |             21.74 |             8.7  |
# | NGO                     |              154629127 |               29 |   51.72 |             41.38 |             6.9  |
# | Non-Profit Organization |              147345923 |               28 |   57.14 |             32.14 |            10.71 |
# | Private Company         |              100010065 |               21 |   52.38 |             38.1  |             9.52 |
#
# Annual Project Volumes
# |   Year |   Total Offered Volume |   Overall Project Delivery |
# |-------:|-----------------------:|---------------------------:|
# |   2000 |            2.46692e+06 |                1.81773e+06 |
# |   2001 |            8.99608e+06 |                5.36191e+06 |
# |   2002 |            7.79211e+06 |                4.22923e+06 |
# |   2003 |            1.4484e+07  |                6.37658e+06 |
# |   2004 |            1.57243e+07 |                6.49942e+06 |
# |   2005 |            1.46083e+07 |                5.16008e+06 |
# |   2006 |            2.31e+07    |                6.21175e+06 |
# |   2007 |            2.33216e+07 |                6.51612e+06 |
# |   2008 |            3.02877e+07 |                1.05936e+07 |
# |   2009 |            2.52002e+07 |                6.55487e+06 |
# |   2010 |            3.12873e+07 |                9.38144e+06 |
# |   2011 |            3.08486e+07 |                9.93935e+06 |
# |   2012 |            2.75565e+07 |                6.22781e+06 |
# |   2013 |            2.60716e+07 |                6.42676e+06 |
# |   2014 |            2.77137e+07 |                7.82311e+06 |
# |   2015 |            2.27204e+07 |                4.64939e+06 |
# |   2016 |            1.73794e+07 |                2.8745e+06  |
# |   2017 |            1.67336e+07 |                2.93364e+06 |
# |   2018 |            1.20546e+07 |                1.41496e+06 |
# |   2019 |            7.69551e+06 |           630057           |
# |   2020 |            4.76126e+06 |           620468           |
# |   2021 |            3.03723e+06 |           186432           |
# |   2022 |       738297           |                0           |
# |   2023 |       214118           |                0           |
