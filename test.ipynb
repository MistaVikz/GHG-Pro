# %%
# %load_ext autoreload
# %autoreload 2

# %%
# project_risk.py
# Author: Mark Vickers
# Date Created: 2024-05-11
# Description: Calculates project risk scores and generates output tables

from utils.io import *
from utils.risk_calculation import *
from utils.analysis import *
import logging
import numpy as np

RISK_BUCKET_COUNT = 5
logging.basicConfig(level=logging.INFO)

if __name__ == "__main__":
    try:
        df_project, df_default_rates, df_recovery_potential = load_and_process_data()

        if valid_project_data(df_project) and check_df_format(df_default_rates, df_recovery_potential):        
            # Calculate Risk Bucket Risk Scores and Ratings for each risk bucket 
            df_project = calculate_risk_bucket_scores(df_project)
            for i in range(1, RISK_BUCKET_COUNT + 1):
                df_project[f'risk_bucket_{i}_rating'] = score_to_rating_vectorized(df_project[f'risk_bucket_{i}_score'])
            
            # Prepare for the simulation
            df_project = calculate_yearly_exposure(df_project, df_default_rates, df_recovery_potential, RISK_BUCKET_COUNT)
            df_project = calculate_yearly_expected_value(df_project)
            df_project = calculate_yearly_standard_deviation(df_project)

            # Run the yearly simulations for all projects
            df_project = run_simulation(df_project)
            overall_expected_value_percentage = df_project[[f'expected_value_percentage_year_{year}' for year in range(1, 11)]].mean(axis=1, skipna=True) * 10
            df_project['overall_project_rating'] = score_to_rating_vectorized(overall_expected_value_percentage)
            
            # Calculate Project Output Tables
            df_counts = pd.DataFrame(df_project['overall_project_rating'].value_counts()).reset_index()
            df_counts.columns = ['overall_project_rating', 'counts']
            top_projects, bottom_projects = calculate_top_bottom_projects(df_project, 10, ['project_id', 'project_name', 'country', 'technology', 'counterparty', 'start_year'])            
            country_table = create_group_table(df_project, 'country')
            technology_table = create_group_table(df_project, 'technology')
            counterparty_table = create_group_table(df_project, 'counterparty')
            total_volumes_per_year = calculate_total_volumes_by_year(df_project)
            
            # Display and Export Data
            display_project_risk_output(df_counts, top_projects, bottom_projects, country_table, technology_table, counterparty_table, total_volumes_per_year)
            output_folder = create_output_folder()
            export_project_risk_output(output_folder, top_projects, bottom_projects, country_table, technology_table, counterparty_table, df_counts, total_volumes_per_year)
            export_ghg_data(output_folder, df_project,df_default_rates,df_recovery_potential)
        else:
            print("Data not loaded properly from GHG_Data.xlsx")

    except FileNotFoundError as e:
        logging.error(f"File not found: {str(e)}")
    except pd.errors.EmptyDataError as e:
        logging.error(f"Empty data error: {str(e)}")
    except TypeError as e:
        logging.error(f"Type error occurred: {str(e)}")
    except ValueError as e:
        logging.error(f"Value error occurred: {str(e)}")
    except Exception as e:
        logging.error(f"An unexpected error occurred: {str(e)}")
        raise
# Out:
# Project Rating Distribution
# | overall_project_rating   |   counts |
# |:-------------------------|---------:|
# | Speculative              |       78 |
# | Investment               |       68 |
# | C                        |        4 |
#
# Highest Performing Projects
# |   rank |   project_id | project_name                           | country      | technology               | counterparty            |   start_year |   average_expected_value |
# |-------:|-------------:|:---------------------------------------|:-------------|:-------------------------|:------------------------|-------------:|-------------------------:|
# |      1 |          120 | Park Hydro Pure Planet                 | South Africa | Waste Management         | Non-Profit Organization |         2007 |                 0.900648 |
# |      2 |           98 | Nature's Way Park Solar                | Canada       | Air Pollution Reduction  | Non-Profit Organization |         2001 |                 0.900018 |
# |      3 |          142 | GreenTech Inc. Recycling Site A        | Mexico       | Waste-to-Energy          | Community Group         |         2009 |                 0.899855 |
# |      4 |           71 | Eco-Friendly South Renewable Solutions | South Korea  | Renewable Energy         | Government Agency       |         2012 |                 0.89983  |
# |      5 |           20 | Geothermal Site D GreenTech Inc.       | Spain        | Waste Management         | Non-Profit Organization |         2008 |                 0.857486 |
# |      6 |          133 | Recycling BioEnergy Systems South      | Italy        | Green Building Practices | NGO                     |         2005 |                 0.853122 |
# |      7 |          106 | Nature's Way Wind South                | India        | Waste Management         | Non-Profit Organization |         2005 |                 0.85068  |
# |      8 |          118 | Sustainable GreenTech Inc. Site A      | India        | Energy Efficiency        | NGO                     |         2006 |                 0.850381 |
# |      9 |           27 | Site A Sustainable ClimateCare Ltd.    | Spain        | Sustainable Agriculture  | Community Group         |         2009 |                 0.850375 |
# |     10 |          113 | South Green GreenTech Inc.             | France       | Carbon Capture           | Community Group         |         2001 |                 0.85031  |
#
# Lowest Performing Projects
# |   rank |   project_id | project_name                       | country      | technology          | counterparty            |   start_year |   average_expected_value |
# |-------:|-------------:|:-----------------------------------|:-------------|:--------------------|:------------------------|-------------:|-------------------------:|
# |      1 |           31 | South Clean Power Co. Eco-Friendly | Germany      | Water Conservation  | NGO                     |         2011 |                 0.298124 |
# |      2 |           99 | Reserve Nature's Way Conservation  | Sweden       | Forestry Management | Community Group         |         2010 |                 0.31691  |
# |      3 |           44 | East Biofuel GreenTech Inc.        | Poland       | Waste-to-Energy     | Community Group         |         2005 |                 0.316982 |
# |      4 |           69 | East Conservation Nature's Way     | South Korea  | Waste Management    | NGO                     |         2001 |                 0.317524 |
# |      5 |          104 | Sustainable BioEnergy Systems East | Brazil       | Waste Management    | Government Agency       |         2013 |                 0.350748 |
# |      6 |          102 | ClimateCare Ltd. Hydro Reserve     | India        | Energy Efficiency   | Non-Profit Organization |         2007 |                 0.353874 |
# |      7 |          122 | Geothermal Park Clean Power Co.    | South Africa | Energy Efficiency   | Non-Profit Organization |         2004 |                 0.401422 |
# |      8 |          148 | Site C Recycling Clean Power Co.   | South Africa | Waste-to-Energy     | Private Company         |         2008 |                 0.402261 |
# |      9 |           87 | EarthFirst Energy West Biofuel     | Turkey       | Waste Management    | Private Company         |         2013 |                 0.402272 |
# |     10 |           58 | Green Site D EcoEnergy Corp.       | Mexico       | Forestry Management | Private Company         |         2011 |                 0.404672 |
#
# Overall Project Rating Distribution by Country
# | country      |   Total Offered Volume |   Total Projects |   C (%) |   Speculative (%) |   Investment (%) |
# |:-------------|-----------------------:|-----------------:|--------:|------------------:|-----------------:|
# | Australia    |               41118572 |                8 |    0    |             50    |            50    |
# | Brazil       |               34889058 |                7 |    0    |             85.71 |            14.29 |
# | Canada       |               26597363 |                5 |    0    |             40    |            60    |
# | China        |               15789187 |                3 |    0    |              0    |           100    |
# | France       |               36896657 |                7 |    0    |             57.14 |            42.86 |
# | Germany      |               37309475 |                7 |   14.29 |             42.86 |            42.86 |
# | India        |               70025933 |               13 |    0    |             46.15 |            53.85 |
# | Indonesia    |               52524984 |               10 |    0    |             80    |            20    |
# | Italy        |               32805325 |                7 |    0    |             42.86 |            57.14 |
# | Japan        |               44614749 |                8 |    0    |             75    |            25    |
# | Mexico       |               41851435 |                8 |    0    |             37.5  |            62.5  |
# | Netherlands  |               19953237 |                4 |    0    |             50    |            50    |
# | Poland       |               32419033 |                6 |   16.67 |             33.33 |            50    |
# | Russia       |               37725505 |                7 |    0    |             71.43 |            28.57 |
# | South Africa |               57086525 |               11 |    0    |             54.55 |            45.45 |
# | South Korea  |               25541717 |                5 |   20    |             20    |            60    |
# | Spain        |               61894882 |               12 |    0    |             58.33 |            41.67 |
# | Sweden       |               38415223 |                7 |   14.29 |             28.57 |            57.14 |
# | Turkey       |               42263002 |                8 |    0    |             50    |            50    |
# | USA          |               36609527 |                7 |    0    |             57.14 |            42.86 |
#
# Overall Project Rating Distribution by Technology
# | technology               |   Total Offered Volume |   Total Projects |   C (%) |   Speculative (%) |   Investment (%) |
# |:-------------------------|-----------------------:|-----------------:|--------:|------------------:|-----------------:|
# | Air Pollution Reduction  |               76358971 |               14 |    0    |             50    |            50    |
# | Carbon Capture           |               79084828 |               15 |    0    |             46.67 |            53.33 |
# | Energy Efficiency        |               69654176 |               13 |    0    |             53.85 |            46.15 |
# | Forestry Management      |               83492877 |               15 |    6.67 |             60    |            33.33 |
# | Green Building Practices |               74505961 |               14 |    0    |             50    |            50    |
# | Renewable Energy         |               70796129 |               14 |    0    |             64.29 |            35.71 |
# | Sustainable Agriculture  |               87861980 |               17 |    0    |             35.29 |            64.71 |
# | Waste Management         |              109606044 |               21 |    4.76 |             42.86 |            52.38 |
# | Waste-to-Energy          |               65569739 |               13 |    7.69 |             61.54 |            30.77 |
# | Water Conservation       |               69400684 |               14 |    7.14 |             64.29 |            28.57 |
#
# Overall Project Rating Distribution by Counterparty
# | counterparty            |   Total Offered Volume |   Total Projects |   C (%) |   Speculative (%) |   Investment (%) |
# |:------------------------|-----------------------:|-----------------:|--------:|------------------:|-----------------:|
# | Community Group         |              182811561 |               34 |    5.88 |             55.88 |            38.24 |
# | Government Agency       |              143193710 |               28 |    0    |             50    |            50    |
# | NGO                     |              183715675 |               36 |    5.56 |             44.44 |            50    |
# | Non-Profit Organization |              129880840 |               24 |    0    |             41.67 |            58.33 |
# | Private Company         |              146729603 |               28 |    0    |             67.86 |            32.14 |
#
# Annual Project Volumes
# |   Year |   Total Offered Volume |   Overall Project Delivery |
# |-------:|-----------------------:|---------------------------:|
# |   2000 |            3.763e+06   |                2.75351e+06 |
# |   2001 |            1.11474e+07 |                8.2905e+06  |
# |   2002 |            1.59203e+07 |                1.09602e+07 |
# |   2003 |            1.65849e+07 |                1.08211e+07 |
# |   2004 |            1.80435e+07 |                1.1989e+07  |
# |   2005 |            1.82385e+07 |                1.24643e+07 |
# |   2006 |            2.40008e+07 |                1.65774e+07 |
# |   2007 |            2.86141e+07 |                2.03173e+07 |
# |   2008 |            2.63766e+07 |                1.7769e+07  |
# |   2009 |            3.06444e+07 |                2.18651e+07 |
# |   2010 |            3.0612e+07  |                2.11842e+07 |
# |   2011 |            2.84217e+07 |                1.91787e+07 |
# |   2012 |            3.17338e+07 |                2.23537e+07 |
# |   2013 |            2.9978e+07  |                1.93311e+07 |
# |   2014 |            3.24155e+07 |                2.1637e+07  |
# |   2015 |            2.93796e+07 |                1.73906e+07 |
# |   2016 |            2.40041e+07 |                1.6043e+07  |
# |   2017 |            1.18886e+07 |                8.31421e+06 |
# |   2018 |            7.37858e+06 |                5.15952e+06 |
# |   2019 |            6.46508e+06 |                4.69442e+06 |
# |   2020 |            3.61218e+06 |                2.79548e+06 |
# |   2021 |            1.15675e+06 |                1.00661e+06 |
# |   2022 |            1.42859e+06 |                1.25218e+06 |
# |   2023 |       157882           |           139121           |
