# %%
# %load_ext autoreload
# %autoreload 2

# %%
# project_risk.py
# Author: Mark Vickers
# Date Created: 2024-05-11
# Description: Calculates project risk scores and generates output tables

from utils.io import *
from utils.risk_calculation import *
from utils.analysis import *
import logging

logging.basicConfig(level=logging.INFO)

if __name__ == "__main__":
    try:
        risk_bucket_count, df_project, df_default_rates, df_recovery_potential = load_and_process_data()
        
        if valid_project_data(df_project,risk_bucket_count) and check_df_format(df_default_rates, df_recovery_potential):        
            
            # Calculate Risk Bucket Risk Scores and Ratings for each risk bucket 
            df_project = calculate_risk_bucket_scores(df_project,risk_bucket_count)        
            for i in range(1, risk_bucket_count + 1):
                df_project[f'risk_bucket_{i}_rating'] = score_to_rating_vectorized(df_project[f'risk_bucket_{i}_score'])
            
            # Prepare for the simulation
            df_project = calculate_yearly_exposure(df_project, df_default_rates, df_recovery_potential, risk_bucket_count)
            df_project = calculate_yearly_expected_value(df_project, risk_bucket_count)
            df_project = calculate_yearly_standard_deviation(df_project,risk_bucket_count)
        
            # Run the yearly simulations for all projects
            df_project = run_simulation(df_project, risk_bucket_count)
            overall_expected_value_percentage = df_project[[f'project_expected_value_percentage_year_{year}' for year in range(1, 11)]].mean(axis=1, skipna=True) * 10
            df_project['overall_project_rating'] = score_to_rating_vectorized(overall_expected_value_percentage)

            # Calculate Project Output Tables
            df_counts = pd.DataFrame(df_project['overall_project_rating'].value_counts()).reset_index()
            df_counts.columns = ['overall_project_rating', 'counts']
            top_projects, bottom_projects = calculate_top_bottom_projects(df_project, 10, ['project_id', 'project_name', 'country', 'technology', 'counterparty', 'start_year'])            
            country_table = create_group_table(df_project, 'country')
            technology_table = create_group_table(df_project, 'technology')
            counterparty_table = create_group_table(df_project, 'counterparty')
            total_volumes_per_year = calculate_total_volumes_by_year(df_project)
            
            # Display and Export Data
            display_project_risk_output(df_counts, top_projects, bottom_projects, country_table, technology_table, counterparty_table, total_volumes_per_year)
            output_folder = create_output_folder()
            export_project_risk_output(output_folder, top_projects, bottom_projects, country_table, technology_table, counterparty_table, df_counts, total_volumes_per_year)
            export_ghg_data(output_folder, df_project,df_default_rates,df_recovery_potential)
        else:
            print("Data not loaded properly from GHG_Data.xlsx")

    except FileNotFoundError as e:
        logging.error(f"File not found: {str(e)}")
    except pd.errors.EmptyDataError as e:
        logging.error(f"Empty data error: {str(e)}")
    except TypeError as e:
        logging.error(f"Type error occurred: {str(e)}")
    except ValueError as e:
        logging.error(f"Value error occurred: {str(e)}")
    except Exception as e:
        logging.error(f"An unexpected error occurred: {str(e)}")
        raise
# Out:
# Project Rating Distribution
# | overall_project_rating   |   counts |
# |:-------------------------|---------:|
# | Investment               |       59 |
# | Speculative              |       39 |
# | C                        |        2 |
#
# Highest Performing Projects
# |   rank |   project_id | project_name                            | country      | technology              | counterparty            |   start_year |   average_expected_value |
# |-------:|-------------:|:----------------------------------------|:-------------|:------------------------|:------------------------|-------------:|-------------------------:|
# |      1 |            7 | Sustainable EarthFirst Energy Site A    | Indonesia    | Air Pollution Reduction | Government Agency       |         2014 |                 0.923246 |
# |      2 |           99 | ClimateCare Ltd. Recycling North        | Australia    | Waste-to-Energy         | Community Group         |         2012 |                 0.922633 |
# |      3 |            6 | Renewable Solutions Geothermal Site A   | Turkey       | Energy Efficiency       | Community Group         |         2000 |                 0.922112 |
# |      4 |            9 | Site D Conservation Renewable Solutions | Indonesia    | Air Pollution Reduction | Non-Profit Organization |         2009 |                 0.911237 |
# |      5 |           23 | EcoEnergy Corp. Park Hydro              | Australia    | Carbon Capture          | Private Company         |         2001 |                 0.910675 |
# |      6 |           16 | Park Pure Planet Eco-Friendly           | Netherlands  | Carbon Capture          | Community Group         |         2011 |                 0.910355 |
# |      7 |           40 | Site A Green Sustainable Futures        | South Africa | Renewable Energy        | Government Agency       |         2013 |                 0.90979  |
# |      8 |           79 | Nature's Way Conservation South         | Japan        | Air Pollution Reduction | Community Group         |         2007 |                 0.909563 |
# |      9 |           55 | Green GreenTech Inc. Park               | South Korea  | Water Conservation      | Community Group         |         2005 |                 0.908984 |
# |     10 |           54 | Nature's Way West Solar                 | Brazil       | Forestry Management     | Community Group         |         2005 |                 0.876633 |
#
# Lowest Performing Projects
# |   rank |   project_id | project_name                          | country      | technology               | counterparty            |   start_year |   average_expected_value |
# |-------:|-------------:|:--------------------------------------|:-------------|:-------------------------|:------------------------|-------------:|-------------------------:|
# |      1 |           47 | Hydro Pure Planet Reserve             | Spain        | Green Building Practices | Private Company         |         2012 |                 0.289003 |
# |      2 |           68 | Sustainable Renewable Solutions East  | Brazil       | Waste-to-Energy          | Community Group         |         2014 |                 0.317916 |
# |      3 |           19 | Site D ClimateCare Ltd. Biofuel       | China        | Carbon Capture           | Non-Profit Organization |         2003 |                 0.405794 |
# |      4 |           59 | ClimateCare Ltd. Sustainable Site B   | India        | Carbon Capture           | Private Company         |         2009 |                 0.412781 |
# |      5 |           88 | Sustainable Futures Solar South       | Russia       | Forestry Management      | Private Company         |         2014 |                 0.427336 |
# |      6 |           61 | South Biofuel Sustainable Futures     | USA          | Forestry Management      | Government Agency       |         2014 |                 0.427426 |
# |      7 |           56 | Site B Eco-Friendly EcoEnergy Corp.   | Canada       | Carbon Capture           | Non-Profit Organization |         2009 |                 0.459414 |
# |      8 |           25 | Reserve Geothermal Pure Planet        | Sweden       | Sustainable Agriculture  | Non-Profit Organization |         2009 |                 0.563912 |
# |      9 |           98 | Conservation Sustainable Futures Park | Sweden       | Waste-to-Energy          | NGO                     |         2005 |                 0.564498 |
# |     10 |           51 | Recycling Pure Planet North           | South Africa | Air Pollution Reduction  | NGO                     |         2014 |                 0.564602 |
#
# Overall Project Rating Distribution by Country
# | country      |   Total Offered Volume |   Total Projects |   C (%) |   Speculative (%) |   Investment (%) |
# |:-------------|-----------------------:|-----------------:|--------:|------------------:|-----------------:|
# | Australia    |               29870657 |                6 |    0    |             16.67 |            83.33 |
# | Brazil       |               31199000 |                6 |   16.67 |             16.67 |            66.67 |
# | Canada       |               32826241 |                6 |    0    |             66.67 |            33.33 |
# | China        |               26043627 |                5 |    0    |             60    |            40    |
# | France       |               26160797 |                5 |    0    |             60    |            40    |
# | Germany      |                4372502 |                1 |    0    |            100    |             0    |
# | India        |               19280107 |                4 |    0    |             25    |            75    |
# | Indonesia    |               15043762 |                3 |    0    |              0    |           100    |
# | Italy        |               16088083 |                3 |    0    |             33.33 |            66.67 |
# | Japan        |               15687237 |                3 |    0    |             33.33 |            66.67 |
# | Mexico       |               20488519 |                4 |    0    |             25    |            75    |
# | Netherlands  |               22958213 |                4 |    0    |              0    |           100    |
# | Poland       |               20785067 |                4 |    0    |             75    |            25    |
# | Russia       |                8038116 |                2 |    0    |             50    |            50    |
# | South Africa |               33366596 |                6 |    0    |             33.33 |            66.67 |
# | South Korea  |               38063592 |                8 |    0    |             25    |            75    |
# | Spain        |               36572372 |                7 |   14.29 |             42.86 |            42.86 |
# | Sweden       |               53837635 |               10 |    0    |             60    |            40    |
# | Turkey       |               29001966 |                5 |    0    |             40    |            60    |
# | USA          |               45657210 |                8 |    0    |             37.5  |            62.5  |
#
# Overall Project Rating Distribution by Technology
# | technology               |   Total Offered Volume |   Total Projects |   C (%) |   Speculative (%) |   Investment (%) |
# |:-------------------------|-----------------------:|-----------------:|--------:|------------------:|-----------------:|
# | Air Pollution Reduction  |               67327340 |               12 |    0    |             33.33 |            66.67 |
# | Carbon Capture           |               62407897 |               12 |    0    |             41.67 |            58.33 |
# | Energy Efficiency        |               19560113 |                4 |    0    |             50    |            50    |
# | Forestry Management      |               47068273 |                9 |    0    |             55.56 |            44.44 |
# | Green Building Practices |               56137435 |               10 |   10    |             30    |            60    |
# | Renewable Energy         |               57684360 |               11 |    0    |             36.36 |            63.64 |
# | Sustainable Agriculture  |               45323473 |                9 |    0    |             44.44 |            55.56 |
# | Waste Management         |               53365166 |               10 |    0    |             40    |            60    |
# | Waste-to-Energy          |               82413486 |               16 |    6.25 |             31.25 |            62.5  |
# | Water Conservation       |               34053756 |                7 |    0    |             42.86 |            57.14 |
#
# Overall Project Rating Distribution by Counterparty
# | counterparty            |   Total Offered Volume |   Total Projects |   C (%) |   Speculative (%) |   Investment (%) |
# |:------------------------|-----------------------:|-----------------:|--------:|------------------:|-----------------:|
# | Community Group         |               94431034 |               19 |    5.26 |             15.79 |            78.95 |
# | Government Agency       |              101991614 |               19 |    0    |             52.63 |            47.37 |
# | NGO                     |               89543040 |               17 |    0    |             47.06 |            52.94 |
# | Non-Profit Organization |              118545528 |               23 |    0    |             43.48 |            56.52 |
# | Private Company         |              120830083 |               22 |    4.55 |             36.36 |            59.09 |
#
# Annual Project Volumes
# |   Year |   Total Offered Volume |   Overall Project Delivery |
# |-------:|-----------------------:|---------------------------:|
# |   2000 |            3.73222e+06 |                3.24999e+06 |
# |   2001 |            7.63066e+06 |                6.36258e+06 |
# |   2002 |            1.0715e+07  |                8.42511e+06 |
# |   2003 |            1.27321e+07 |                9.31919e+06 |
# |   2004 |            1.09347e+07 |                8.05131e+06 |
# |   2005 |            1.19746e+07 |                8.70058e+06 |
# |   2006 |            1.13013e+07 |                8.38165e+06 |
# |   2007 |            1.21411e+07 |                9.36274e+06 |
# |   2008 |            1.14918e+07 |                8.74805e+06 |
# |   2009 |            2.09478e+07 |                1.63532e+07 |
# |   2010 |            2.21656e+07 |                1.60809e+07 |
# |   2011 |            1.80907e+07 |                1.30769e+07 |
# |   2012 |            2.06831e+07 |                1.46615e+07 |
# |   2013 |            2.10451e+07 |                1.48384e+07 |
# |   2014 |            2.0899e+07  |                1.3804e+07  |
# |   2015 |            1.43442e+07 |                9.66602e+06 |
# |   2016 |            1.60303e+07 |                1.05118e+07 |
# |   2017 |            1.44013e+07 |                9.71237e+06 |
# |   2018 |            9.18289e+06 |                6.27255e+06 |
# |   2019 |            6.70833e+06 |                5.00744e+06 |
# |   2020 |            4.231e+06   |                3.16401e+06 |
# |   2021 |            2.85158e+06 |                2.30766e+06 |
# |   2022 |            1.18959e+06 |                1.06491e+06 |
# |   2023 |       289102           |           258210           |
