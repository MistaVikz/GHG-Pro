# %%
# %load_ext autoreload
# %autoreload 2

# %%
# project_risk.py
# Author: Mark Vickers
# Date Created: 2024-05-11
# Description: Calculates project risk scores and generates output tables

from utils.io import *
from utils.risk_calculation import *
from utils.analysis import *
import logging

logging.basicConfig(level=logging.INFO)

if __name__ == "__main__":
    try:
        risk_bucket_count, risk_factor_count, df_project, df_default_rates, df_recovery_potential = load_and_process_data()

        if valid_project_data(df_project,risk_bucket_count,risk_factor_count) and check_df_format(df_default_rates, df_recovery_potential):        

            # Calculate Risk Bucket Risk Scores and Ratings for each risk bucket 
            df_project = calculate_risk_bucket_scores(df_project,risk_bucket_count)        
            for i in range(1, risk_bucket_count + 1):
                df_project[f'risk_bucket_{i}_rating'] = score_to_rating_vectorized(df_project[f'risk_bucket_{i}_score'])
            
            # Prepare for the simulation
            df_project = calculate_yearly_exposure(df_project, df_default_rates, df_recovery_potential, risk_bucket_count)
            df_project = calculate_yearly_expected_value(df_project, risk_bucket_count)
            df_project = calculate_yearly_standard_deviation(df_project,risk_bucket_count)
        
            # Run the yearly simulations for all projects
            df_project = run_simulation(df_project, risk_bucket_count)
            overall_expected_value_percentage = df_project[[f'project_expected_value_percentage_year_{year}' for year in range(1, 11)]].mean(axis=1, skipna=True) * 10
            df_project['overall_project_rating'] = score_to_rating_vectorized(overall_expected_value_percentage)

            # Calculate Project Output Tables
            df_counts = pd.DataFrame(df_project['overall_project_rating'].value_counts()).reset_index()
            df_counts.columns = ['overall_project_rating', 'counts']
            top_projects, bottom_projects = calculate_top_bottom_projects(df_project, 10, ['project_id', 'project_name', 'country', 'technology', 'counterparty', 'start_year'])            
            country_table = create_group_table(df_project, 'country')
            technology_table = create_group_table(df_project, 'technology')
            counterparty_table = create_group_table(df_project, 'counterparty')
            total_volumes_per_year = calculate_total_volumes_by_year(df_project)
            
            # Display and Export Data
            display_project_risk_output(df_counts, top_projects, bottom_projects, country_table, technology_table, counterparty_table, total_volumes_per_year)
            output_folder = create_output_folder()
            export_project_risk_output(output_folder, top_projects, bottom_projects, country_table, technology_table, counterparty_table, df_counts, total_volumes_per_year)
            export_ghg_data(output_folder, df_project,df_default_rates,df_recovery_potential)
        else:
            print("Data not loaded properly from GHG_Data.xlsx")

    except FileNotFoundError as e:
        logging.error(f"File not found: {str(e)}")
    except pd.errors.EmptyDataError as e:
        logging.error(f"Empty data error: {str(e)}")
    except TypeError as e:
        logging.error(f"Type error occurred: {str(e)}")
    except ValueError as e:
        logging.error(f"Value error occurred: {str(e)}")
    except Exception as e:
        logging.error(f"An unexpected error occurred: {str(e)}")
        raise
# Out:
# Project Rating Distribution
# | overall_project_rating   |   counts |
# |:-------------------------|---------:|
# | Speculative              |      114 |
# | Investment               |       33 |
# | C                        |        3 |
#
# Highest Performing Projects
# |   rank |   project_id | project_name                            | country     | technology              | counterparty            |   start_year |   average_expected_value |
# |-------:|-------------:|:----------------------------------------|:------------|:------------------------|:------------------------|-------------:|-------------------------:|
# |      1 |           92 | Site D Recycling Renewable Solutions    | Russia      | Renewable Energy        | Community Group         |         2011 |                 0.923052 |
# |      2 |          141 | Solar Site D Pure Planet                | Turkey      | Waste Management        | Private Company         |         2003 |                 0.922341 |
# |      3 |           96 | GreenTech Inc. Hydro Site A             | Japan       | Carbon Capture          | Non-Profit Organization |         2005 |                 0.921999 |
# |      4 |          139 | Sustainable Sustainable Futures Reserve | Netherlands | Sustainable Agriculture | Government Agency       |         2012 |                 0.921831 |
# |      5 |           50 | Nature's Way South Green                | Turkey      | Waste-to-Energy         | Private Company         |         2003 |                 0.899153 |
# |      6 |            7 | Site B EcoEnergy Corp. Eco-Friendly     | Poland      | Waste-to-Energy         | Community Group         |         2009 |                 0.899008 |
# |      7 |           27 | Site B Sustainable Nature's Way         | Netherlands | Water Conservation      | Government Agency       |         2008 |                 0.892762 |
# |      8 |          114 | North Geothermal EarthFirst Energy      | Spain       | Renewable Energy        | Community Group         |         2013 |                 0.885298 |
# |      9 |           95 | Reserve Geothermal GreenTech Inc.       | Mexico      | Air Pollution Reduction | NGO                     |         2009 |                 0.88453  |
# |     10 |            9 | West ClimateCare Ltd. Wind              | South Korea | Carbon Capture          | NGO                     |         2009 |                 0.878203 |
#
# Lowest Performing Projects
# |   rank |   project_id | project_name                       | country      | technology              | counterparty            |   start_year |   average_expected_value |
# |-------:|-------------:|:-----------------------------------|:-------------|:------------------------|:------------------------|-------------:|-------------------------:|
# |      1 |           32 | BioEnergy Systems Park Biofuel     | Sweden       | Renewable Energy        | Non-Profit Organization |         2004 |                 0.313831 |
# |      2 |           11 | Renewable Solutions Site D Biofuel | Poland       | Air Pollution Reduction | NGO                     |         2004 |                 0.318604 |
# |      3 |          142 | Green Site C GreenTech Inc.        | Turkey       | Carbon Capture          | Private Company         |         2001 |                 0.32512  |
# |      4 |          123 | Solar ClimateCare Ltd. Site D      | France       | Carbon Capture          | Private Company         |         2011 |                 0.362157 |
# |      5 |           12 | Nature's Way Hydro South           | Canada       | Energy Efficiency       | Government Agency       |         2008 |                 0.365566 |
# |      6 |          138 | EcoEnergy Corp. Recycling Reserve  | Australia    | Carbon Capture          | NGO                     |         2006 |                 0.365697 |
# |      7 |           47 | Biofuel Site D Nature's Way        | South Africa | Carbon Capture          | Non-Profit Organization |         2000 |                 0.367069 |
# |      8 |          109 | Geothermal South BioEnergy Systems | Sweden       | Air Pollution Reduction | NGO                     |         2009 |                 0.369174 |
# |      9 |           82 | Geothermal North ClimateCare Ltd.  | India        | Air Pollution Reduction | Government Agency       |         2004 |                 0.41142  |
# |     10 |          117 | Clean Power Co. East Sustainable   | Spain        | Waste-to-Energy         | Private Company         |         2002 |                 0.411557 |
#
# Overall Project Rating Distribution by Country
# | country      |   Total Offered Volume |   Total Projects |   C (%) |   Speculative (%) |   Investment (%) |
# |:-------------|-----------------------:|-----------------:|--------:|------------------:|-----------------:|
# | Australia    |               38348951 |                7 |    0    |             57.14 |            42.86 |
# | Brazil       |               37805230 |                7 |    0    |             85.71 |            14.29 |
# | Canada       |               57341457 |               10 |    0    |             90    |            10    |
# | China        |               10233590 |                2 |    0    |            100    |             0    |
# | France       |               32588620 |                7 |    0    |            100    |             0    |
# | Germany      |               13488826 |                3 |    0    |             66.67 |            33.33 |
# | India        |               33493241 |                7 |    0    |             71.43 |            28.57 |
# | Indonesia    |               32326551 |                6 |    0    |             83.33 |            16.67 |
# | Italy        |               48921191 |                9 |    0    |             88.89 |            11.11 |
# | Japan        |               51844131 |               10 |    0    |             70    |            30    |
# | Mexico       |               30344999 |                6 |    0    |             50    |            50    |
# | Netherlands  |               49530331 |                9 |    0    |             77.78 |            22.22 |
# | Poland       |               43880252 |                9 |   11.11 |             55.56 |            33.33 |
# | Russia       |               70666916 |               14 |    0    |             78.57 |            21.43 |
# | South Africa |               33247317 |                6 |    0    |             66.67 |            33.33 |
# | South Korea  |               35848200 |                7 |    0    |             85.71 |            14.29 |
# | Spain        |               36464704 |                7 |    0    |             85.71 |            14.29 |
# | Sweden       |               39965587 |                8 |   12.5  |             75    |            12.5  |
# | Turkey       |               56400110 |               10 |   10    |             60    |            30    |
# | USA          |               28405891 |                6 |    0    |             83.33 |            16.67 |
#
# Overall Project Rating Distribution by Technology
# | technology               |   Total Offered Volume |   Total Projects |   C (%) |   Speculative (%) |   Investment (%) |
# |:-------------------------|-----------------------:|-----------------:|--------:|------------------:|-----------------:|
# | Air Pollution Reduction  |              103904028 |               22 |    4.55 |             68.18 |            27.27 |
# | Carbon Capture           |              102038863 |               18 |    5.56 |             66.67 |            27.78 |
# | Energy Efficiency        |               64641683 |               13 |    0    |            100    |             0    |
# | Forestry Management      |               46791667 |                9 |    0    |             66.67 |            33.33 |
# | Green Building Practices |               40360703 |                8 |    0    |             75    |            25    |
# | Renewable Energy         |               86607784 |               16 |    6.25 |             62.5  |            31.25 |
# | Sustainable Agriculture  |               59871375 |               11 |    0    |             90.91 |             9.09 |
# | Waste Management         |               63585488 |               12 |    0    |             75    |            25    |
# | Waste-to-Energy          |              102991561 |               19 |    0    |             73.68 |            26.32 |
# | Water Conservation       |              110352943 |               22 |    0    |             86.36 |            13.64 |
#
# Overall Project Rating Distribution by Counterparty
# | counterparty            |   Total Offered Volume |   Total Projects |   C (%) |   Speculative (%) |   Investment (%) |
# |:------------------------|-----------------------:|-----------------:|--------:|------------------:|-----------------:|
# | Community Group         |              113583680 |               21 |    0    |             71.43 |            28.57 |
# | Government Agency       |              176280511 |               35 |    0    |             85.71 |            14.29 |
# | NGO                     |              190816271 |               37 |    2.7  |             64.86 |            32.43 |
# | Non-Profit Organization |              155397210 |               29 |    3.45 |             79.31 |            17.24 |
# | Private Company         |              145068423 |               28 |    3.57 |             78.57 |            17.86 |
#
# Annual Project Volumes
# |   Year |   Total Offered Volume |   Overall Project Delivery |
# |-------:|-----------------------:|---------------------------:|
# |   2000 |            2.82671e+06 |                1.91359e+06 |
# |   2001 |            9.09266e+06 |                5.68759e+06 |
# |   2002 |            1.42644e+07 |                8.57707e+06 |
# |   2003 |            1.68599e+07 |                9.40295e+06 |
# |   2004 |            1.98856e+07 |                1.19556e+07 |
# |   2005 |            2.3932e+07  |                1.3926e+07  |
# |   2006 |            2.38482e+07 |                1.45415e+07 |
# |   2007 |            2.48552e+07 |                1.52098e+07 |
# |   2008 |            2.68616e+07 |                1.6491e+07  |
# |   2009 |            3.07164e+07 |                1.86696e+07 |
# |   2010 |            3.13145e+07 |                1.97764e+07 |
# |   2011 |            3.6104e+07  |                2.10421e+07 |
# |   2012 |            3.39268e+07 |                2.06088e+07 |
# |   2013 |            3.30081e+07 |                1.97819e+07 |
# |   2014 |            2.94598e+07 |                1.79216e+07 |
# |   2015 |            2.59547e+07 |                1.52914e+07 |
# |   2016 |            1.75576e+07 |                1.0047e+07  |
# |   2017 |            1.25724e+07 |                7.33726e+06 |
# |   2018 |            6.54464e+06 |                4.22962e+06 |
# |   2019 |            4.54317e+06 |                3.27142e+06 |
# |   2020 |            1.65293e+06 |                1.32208e+06 |
# |   2021 |            1.3874e+06  |                1.07318e+06 |
